# %% [markdown]
# # 視覺化
#
# ## 郭耀仁

# %% [markdown]
# ## 視覺化的力量
#
# - [Hans Rosling](https://www.youtube.com/watch?v=jbkSRLYSojo)
#
# > He rose to international celebrity status after producing a [Ted Talk](https://www.ted.com/talks/hans_rosling_shows_the_best_stats_you_ve_ever_seen?language=zh-tw) in which he promoted the use of data to explore development issues.
# > [Hans Rosling - Wikipedia](https://en.wikipedia.org/wiki/Hans_Rosling)

# %% [markdown]
# ## Matplotlib
#
# - Python 基礎的繪圖套件
#
# ```python
# %matplotlib inline # 讓圖能夠在 Notebook 中顯示
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# ## 使用 `scatter()` 方法畫散佈圖
#
# - `xlabel()` X 軸標籤
# - `ylabel()` Y 軸標籤
# - `title()` 圖標題
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(1, 11)
# y = 2*x
# plt.scatter(x, y)
# plt.xlabel("x")
# plt.ylabel("y")
# plt.title("Scatter Plot")
# plt.show()
# ```

# %%
# 不同類別的點使用不同形狀與顏色
import pandas as pd

url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/bezdekIris.data"
iris = pd.read_csv(url, names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])
setosa = iris[iris.species == "Iris-setosa"]
versicolor = iris[iris.species == "Iris-versicolor"]
virginica = iris[iris.species == "Iris-virginica"]

plt.plot(setosa.sepal_length, setosa.sepal_width, 'rs', label = "setosa") # 紅方塊
plt.plot(versicolor.sepal_length, versicolor.sepal_width, 'g*', label = "versicolor") # 綠星星
plt.plot(virginica.sepal_length, virginica.sepal_width, 'bD', label = "virginica") # 藍菱形
plt.legend(loc = 'lower right')
plt.show()

# %%
# 畫線圖
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 6.5, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y = sin(x)")
plt.show()

# %%
## 將兩個線圖疊在一起
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y = sin(x) & y = cos(x)")
plt.show()

# %%
# 同時畫左右兩個線圖
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(1, 2, 1) # 要畫 (1, 2) 中的第一個
plt.plot(x, y_sin, "r--") # 紅色虛線
plt.ylabel("y")
plt.title("y = sin(x)")
plt.subplot(1, 2, 2) # 要畫 (1, 2) 中的第二個
plt.plot(x, y_cos, "b") # 藍色實線
plt.title("y = cos(x)")
plt.show()

# %% [markdown]
# ## 直方圖
#
# - 使用 `numpy.random` 產生隨機變數
# - 用 `hist()` 方法視覺化
#
# ```python
# import numpy as np
# import matplotlib.pyplot as ply
#
# normal_samples = np.random.normal(size = 1000)
# uniform_samples = np.random.uniform(size = 1000)
#
# plt.subplot(1, 2, 1) # 要畫 (1, 2) 中的第一個
# plt.hist(normal_samples)
# plt.title("Normal Dist")
# plt.subplot(1, 2, 2) # 要畫 (1, 2) 中的第二個
# plt.hist(uniform_samples)
# plt.title("Uniform Dist")
# plt.show()
# ```

# %%
# 把兩個直方圖疊在一起
import numpy as np
import matplotlib.pyplot as ply

normal_samples_1 = np.random.normal(size = 1000)
normal_samples_2 = np.random.normal(size = 1000, loc = 3)
normal_samples = np.column_stack((normal_samples_1, normal_samples_2))

plt.hist(normal_samples, color = ["g", "b"], bins = 30)
plt.show()

# %% [markdown]
# ## 長條圖
#
# - `bar()` 與 `barh()` 方法
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
#
# url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/bezdekIris.data"
# iris = pd.read_csv(url, names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])
# average = np.mean(iris.values[:, 0:4], axis = 0)
# category = range(iris.shape[1] - 1)
#
# plt.subplot(1, 2, 1)
# plt.barh(category, average, color = "b", alpha = 0.5, align = "center")
# plt.title("Horizontal Bar Chart")
# plt.yticks(category, iris.columns[0:4])
# plt.subplot(1, 2, 2)
# plt.bar(category, average, color = "r", alpha = 0.5, align = "center")
# plt.title("Vertical Bar Chart")
# plt.xticks(category, iris.columns[0:4], rotation='vertical')
# plt.show()
# ```

# %% [markdown]
# ## 延伸閱讀
#
# - [Matplotlib Gallery](http://matplotlib.org/gallery.html)
# - [Seaborn: statistical data visualization](https://seaborn.pydata.org/)
# - [Bokeh](http://bokeh.pydata.org/en/latest/)
